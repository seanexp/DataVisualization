# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(sum(map(ord, "aesthetics")))

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %%
sns.set()
sinplot()

# %%
[x for x in dir(sns) if x.endswith('plot')]
# Out:
# ['barplot',
#  'boxplot',
#  'coefplot',
#  'countplot',
#  'distplot',
#  'factorplot',
#  'interactplot',
#  'jointplot',
#  'kdeplot',
#  'lmplot',
#  'lvplot',
#  'miscplot',
#  'pairplot',
#  'palplot',
#  'pointplot',
#  'puppyplot',
#  'regplot',
#  'residplot',
#  'rugplot',
#  'stripplot',
#  'swarmplot',
#  'tsplot',
#  'violinplot']
